# %%
import json

with open("dp_rollout_states_actions.json", "r") as f:
    data = json.load(f)


print(data.keys())
# Out:
# dict_keys(['states', 'actions', 'rewards', 'rewards_dense', 'time'])

# %%
import matplotlib.pyplot as plt

time = data["time"]
rewards = data["rewards"]

fig, ax = plt.subplots()

print(len(time))
print(time[-1])
ax.set_xlabel("Time [s]")
ax.set_ylabel("reward [m]")
ax.plot(time, rewards)
ax.grid()
print(time[-1] / len(time))

print(0.002*5000)
# Out:
# 3490
# 6.979999999999453
# 0.0019999999999998435
# 10.0
